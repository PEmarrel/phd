# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import skew

from collections import Counter
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from data.pipData import * 
from modelSGNS import *
from dataSet import *
from visuEmbedding import *
from tool import *
# Out:
# [nltk_data] Downloading package punkt_tab to /home/pe/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/pe/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Explanation
# The selection of negative samples is an important aspect of Skip-Gram with Negative Samples (SGNS). The original SGNS relies on the overall frequency of words to select the most frequent words. These are then excellent candidates for negative examples. But a child cannot use statistics on a corpus as large as word2vec. In this file, we will look at different ways to select the best negative samples.

# %% [markdown]
# # Data
# Selected corpus :
# data/GoodNightGorilla_Intonation.txt

# %%
data = prepare_data_with_intonation(
    file_path="./data/GoodNightGorilla_Intonation.txt",
    language='english',
    remove_accent=True,
    remove_punct=True,
    keep_apostrophes=False,
    contraction_map={# specific to corpus 
        "that's" : "thatis",
        "it's" : "itis",
        "don't": "donot",
        "doesn't": "doesnot",},
    stop_words=["s", "n't"],
    break_line=False
)

texts, intonations = separate_text_intonation(data)

# %% [markdown]
# ## Create a dataset (positive pair)

# %%
dataset = W2V_weighted_DataSet_v2(
    sentences=texts, 
    intonations=intonations,
    nb_neg=5,
    window_size=6
)

# %%
corpus_one_list = []
for paragraph in texts:
    corpus_one_list.extend(paragraph)
freq_word = Counter(corpus_one_list)

freq_sorted = freq_word.most_common()
print(freq_sorted)
words = []
freqs = []

for word, freq in freq_sorted:
    words.append(word)
    freqs.append(freq)

plt.figure(figsize=(12, 6))
plt.bar(words[:20], freqs[:20])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# [('the', 192), ('is', 117), ('he', 69), ('look', 48), ('to', 46), ('and', 42), ('a', 33), ('his', 29), ('at', 28), ('gorilla', 27), ('zookeeper', 25), ('in', 24), ('it', 24), ('good', 21), ('night', 21), ('are', 20), ('little', 19), ('big', 18), ('mouse', 18), ('she', 18), ('up', 17), ('who', 16), ('all', 16), ('right', 15), ('but', 15), ('they', 15), ('back', 15), ('there', 13), ('lion', 13), ('bed', 13), ('her', 13), ('on', 12), ('banana', 12), ('giraffe', 12), ('you', 11), ('that', 11), ('walking', 11), ('see', 10), ('oh', 10), ('out', 10), ('him', 10), ('has', 9), ('says', 9), ('elephant', 9), ('of', 9), ('wife', 9), ('keys', 8), ('doesnot', 8), ('now', 8), ('everyone', 8), ('click', 7), ('what', 7), ('sleep', 7), ('so', 7), ('still', 7), ('hyena', 7), ('them', 7), ('armadillo', 7), ('saying', 6), ('room', 6), ('where', 6), ('with', 6), ('behind', 6), ('looks', 6), ('for', 6), ('way', 6), ('next', 6), ('asleep', 6), ('can', 5), ('going', 5), ('inside', 5), ('following', 5), ('coming', 5), ('itis', 5), ('this', 5), ('like', 5), ('over', 5), ('zoo', 5), ('house', 5), ('just', 5), ('dark', 4), ('my', 4), ('sneaky', 4), ('away', 4), ('open', 4), ('door', 4), ('climbing', 4), ('else', 4), ('again', 4), ('here', 4), ('long', 4), ('our', 4), ('do', 4), ('peeking', 4), ('animals', 4), ('across', 4), ('from', 4), ('thinks', 4), ('too', 4), ('fast', 4), ('those', 4), ('eyes', 4), ('flashlight', 3), ('goodness', 3), ('no', 3), ('reaching', 3), ('want', 3), ('does', 3), ('pink', 3), ('thing', 3), ('balloon', 3), ('holding', 3), ('hand', 3), ('know', 3), ('dragging', 3), ('yellow', 3), ('pull', 3), ('thump', 3), ('letting', 3), ('time', 3), ('fuzzy', 3), ('tall', 3), ('one', 3), ('neck', 3), ('high', 3), ('pulling', 3), ('silly', 3), ('wall', 3), ('i', 3), ('ready', 3), ('wait', 3), ('step', 3), ('friend', 3), ('by', 3), ('into', 3), ('covers', 3), ('drawer', 3), ('wide', 3), ('awake', 3), ('march', 3), ('say', 2), ('off', 2), ('squeak', 2), ('watching', 2), ('stay', 2), ('wants', 2), ('floating', 2), ('let', 2), ('happened', 2), ('cage', 2), ('unlock', 2), ('shine', 2), ('being', 2), ('very', 2), ('tiptoe', 2), ('uh', 2), ('sky', 2), ('hard', 2), ('busy', 2), ('twist', 2), ('wow', 2), ('white', 2), ('having', 2), ('snack', 2), ('quiet', 2), ('how', 2), ('smiling', 2), ('heavy', 2), ('string', 2), ('toy', 2), ('tiny', 2), ('tap', 2), ('have', 2), ('was', 2), ('parade', 2), ('friends', 2), ('anymore', 2), ('stairs', 2), ('green', 2), ('gate', 2), ('lights', 2), ('surprise', 2), ('through', 2), ('head', 2), ('scuttle', 2), ('picture', 2), ('bedroom', 2), ('think', 2), ('even', 2), ('sitting', 2), ('tired', 2), ('under', 2), ('yawn', 2), ('lying', 2), ('down', 2), ('foot', 2), ('curtains', 2), ('curled', 2), ('cat', 2), ('standing', 2), ('put', 2), ('lamp', 2), ('dear', 2), ('husband', 2), ('tucked', 2), ('floor', 2), ('not', 2), ('voice', 2), ('be', 2), ('heard', 2), ('blink', 2), ('hear', 2), ('come', 2), ('clomp', 2), ('warm', 2), ('finally', 2), ('animal', 1), ('closer', 1), ('taking', 1), ('stealing', 1), ('belt', 1), ('jingle', 1), ('jangle', 1), ('sees', 1), ('doing', 1), ('everything', 1), ('bicycle', 1), ('tire', 1), ('swing', 1), ('follow', 1), ('donot', 1), ('fly', 1), ('used', 1), ('free', 1), ('byebye', 1), ('whoosh', 1), ('working', 1), ('using', 1), ('putting', 1), ('key', 1), ('lock', 1), ('lives', 1), ('mane', 1), ('make', 1), ('sound', 1), ('rooooar', 1), ('bone', 1), ('past', 1), ('or', 1), ('stretch', 1), ('your', 1), ('streeeeetch', 1), ('waiting', 1), ('party', 1), ('helper', 1), ('strong', 1), ('wheels', 1), ('guessed', 1), ('shell', 1), ('leaning', 1), ('toys', 1), ('baby', 1), ('bottle', 1), ('orange', 1), ('doll', 1), ('getting', 1), ('join', 1), ('legs', 1), ('quietly', 1), ('last', 1), ('never', 1), ('gives', 1), ('walked', 1), ('steps', 1), ('front', 1), ('go', 1), ('inviting', 1), ('themselves', 1), ('other', 1), ('lawn', 1), ('making', 1), ('grey', 1), ('comes', 1), ('purple', 1), ('hurrying', 1), ('catch',  ...

# %% [markdown]
# # Distribution of original SGNS

# %%
freq_list = [freq_word.get(i, 0) for i in dataset.encoder.keys()]
unigram = [f**0.75 for f in freq_list]

word_proba = {}
for word, token in dataset.encoder.items():
    word_proba[word] = unigram[token]

print(word_proba)


sorted_dict = {key: value for key, 
               value in sorted(word_proba.items(), 
                               key=lambda item: item[1], reverse=True)}

print(sorted_dict)

plt.figure(figsize=(12, 6))
plt.bar(list(sorted_dict.keys())[:20], list(sorted_dict.values())[:20])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Use intonation of word

# %%
token_importance = dataset.word_importance
print(token_importance)

word_importance = {}

for token, importance in token_importance.items():
    word_importance[dataset.decoder[token]] = importance
    
print(word_importance)

# %%
sorted_dict = {key: value for key, 
               value in sorted(word_importance.items(), 
                               key=lambda item: item[1], reverse=True)}

plt.figure(figsize=(12, 6))
plt.bar(list(sorted_dict.keys())[0:60], list(sorted_dict.values())[0:60])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
plt.bar(list(sorted_dict.keys())[-20:], list(sorted_dict.values())[-20:])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
